# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np
import seaborn as sns
from pandas.io.json import json_normalize
import folium
import requests
from collections import Counter, defaultdict

# %% [markdown]
# ### Companies Mongodb:

# %%
conn = MongoClient("localhost:27017")
conn.list_database_names()
db = conn.get_database("ironhack")
db.list_collection_names()
# Out:
# ['restaurants', 'books', 'companies', 'countries-small']

# %%
companies = db.get_collection("companies")
companies.find_one({}).keys()
# Out:
# dict_keys(['_id', 'name', 'permalink', 'crunchbase_url', 'homepage_url', 'blog_url', 'blog_feed_url', 'twitter_username', 'category_code', 'number_of_employees', 'founded_year', 'founded_month', 'founded_day', 'deadpooled_year', 'tag_list', 'alias_list', 'email_address', 'phone_number', 'description', 'created_at', 'updated_at', 'overview', 'image', 'products', 'relationships', 'competitions', 'providerships', 'total_money_raised', 'funding_rounds', 'investments', 'acquisition', 'acquisitions', 'offices', 'milestones', 'video_embeds', 'screenshots', 'external_links', 'partners'])

# %% [markdown]
# From this dataset we will select all the companies that where founded during and after the economic crisis of 2009. Showing only the following keys:
#
#     - name
#     - founded_year (We asume the economic crisis was fully settled in 2009, although LB crashed in sept. 2008)
#     - offices (nested array, to find location of the office)

# %%
companies.find(
        {'founded_year': {"$gt": 2008}},   
    {"name": 1, 'founded_year': 1, "offices" : 1, "_id" : 0})

# %%
df_companies = pd.DataFrame(companies.find(
        {'founded_year': {"$gt": 2008}},   
    {"name": 1, 'founded_year': 1, "offices" : 1, "_id" : 0}))

# %% [markdown]
# Next we create a new raw for each office location without loosing its initial index:

# %%
df_companies = df_companies.explode('offices')

# %%
df_companies.sample(3)
# Out:
#            name  founded_year  \
# 422    Leadjini          2009
# 336  Foursquare          2009
# 66       Garena          2009
#
#                                                offices
# 422                                                NaN
# 336  {'description': '', 'address1': '568 Broadway'...
# 66   {'description': '', 'address1': '', 'address2'...

# %%
df_companies.offices.isna().sum()
# Out:
# 312

# %%
df_companies = df_companies.dropna()

# %%
df_companies["city"] = df_companies["offices"].apply(lambda o : o.get("city"))

# %%
df_companies.head()
# Out:
#        name  founded_year                                            offices  \
# 0  Mokitown          2011  {'description': None, 'address1': None, 'addre...
# 1  CircleUp          2011  {'description': '', 'address1': '', 'address2'...
# 2   PeekYou          2012  {'description': None, 'address1': None, 'addre...
# 3     GENWI          2010  {'description': '', 'address1': '4966 El Camin...
# 4     headr          2012  {'description': '', 'address1': 'Ritterstr. 12...
#
#             city
# 0           None
# 1  San Francisco
# 2       New York
# 3      Los Altos
# 4         Berlin

# %% [markdown]
#  The cities to look for:
#
#     - Madrid
#     - New York
#     - San Francisco
#     - London
#     - Hannover

# %%
selected_words = ["Madrid", "New York", "San Francisco", "London", "Hannover"]

# %%
df_companies.city.value_counts()[selected_words]
# Out:
# Madrid            4
# New York         39
# San Francisco    50
# London           27
# Hannover          1
# Name: city, dtype: int64

# %% [markdown]
# The selected city is San Francisco

# %%
df_companies =  df_companies[df_companies.city == 'San Francisco']

# %%
df_companies["latitude"] = df_companies["offices"].apply(lambda o : o.get("latitude"))

# %%
df_companies["longitude"] = df_companies["offices"].apply(lambda o : o.get("longitude"))

# %%
df_companies
# Out:
#                           name  founded_year  \
# 1                     CircleUp          2011
# 11                   Widgetbox          2012
# 17                   YouNoodle          2010
# 22                      Ninite          2009
# 28                   Macroaxis          2009
# 33            Supercool School          2009
# 62                     Advisor          2011
# 64                       Prezi          2009
# 71                   Integrate          2010
# 81                   Integrate          2010
# 91                    perceptu          2009
# 102                     Webtab          2010
# 103                 Formspring          2009
# 107     Emotive Communications          2011
# 109                  Stupeflix          2009
# 120                   Storenvy          2009
# 140                      Indee          2010
# 144                    JumpFox          2009
# 166                     Heyzap          2009
# 174                       Meez          2009
# 241                    CSRware          2009
# 257            Startup Revival          2009
# 264                     Fliggo          2012
# 286          Founder Institute          2009
# 288                    MyLikes          2010
# 290  The Vertical Action Group          2009
# 314                       Honk          2009
# 321                    thredUP          2009
# 325                  Cloudkick          2009
# 336                 Foursquare          2009
# 357                 IBWIRE Inc          2009
# 376                       Pict          2012
# 392             One Kings Lane          2009
# 411                    CoTweet          2009
# 425                    Twazzup          2009
# 442                   Shopseen          2013
# 493                    Mashape          2010
# 495               LendingKarma          2009
# 514                   Nextstop          2009
# 515                     Square          2009
# 550                  SimpleGeo          2009
# 559                  AppNinjas          2009
# 570                       gdgt          2009
# 621                    Fliptop          2010
# 660                 ReTargeter          2009
# 665              Urban Airship          2009
# 682              Finest Expert          2009
# 700                       Vevo          2009
# 768                     TwtBks          2009
# 790                   Fuze Box          2009
#
#                                                offices           city  \
# 1    {'description': '', 'address1': '', 'address2'...  San Francisco
# 11   {'description': None, 'address1': None, 'addre...  San Francisco
# 17   {'description': '', 'address1': '330 Townsend ...  San Francisco
# 22   {'description': '', 'address1': '955 Bush St.'...  San Francisco
# 28   {'description': 'Macroaxis Inc', 'address1': '...  San Francisco
# 33   {'description': None, 'address1': '1176 South ...  San Francisco
# 62   {'description': 'San Francisco HQ', 'address1'...  San Francisco
# 64   {'description': 'SF Office', 'address1': '735 ...  San Francisco
# 71   {'description': 'San Francisco Office', 'addre...  San Francisco
# 81   {'description': 'San Francisco Office', 'addre...  San Francisco
# 91   {'description': 'HQ', 'address1': '', 'address...  San Francisco
# 102  {'description': 'Corporate Headquarters', 'add...  San Francisco
# 103  {'description': 'Formspring', 'address1': '', ...  San Francisco
# 107  {'description': 'HQ', 'address1': '345 Califor...  San Francisco
# 109  {'description': 'San Francisco', 'address1': '...  San Francisco
# 120  {'description': 'Storenvy HQ', 'address1': '21...  San Francisco
# 140  {'description': 'Headquarters', 'address1': '1...  San Francisco
# 144  {'description': 'HQ', 'address1': '544 Natoma'...  San Francisco
# 166  {'description': 'Head Quaters', 'address1': '3...  San Francisco
# 174  {'description': '', 'address1': '620 Folsom St...  San Francisco
# 241  {'description': 'San Francisco HQ', 'address1'...  San Francisco
# 257  {'description': 'San Francisco', 'address1': '...  San Francisco
# 264  {'description': '', 'address1': '', 'address2'...  San Francisco
# 286  {'description': 'The Founder Institute', 'addr...  San Francisco
# 288  {'description': '', 'address1': '1000 Brannan ...  San Francisco
# 290  {'description': 'World Headquarters', 'address...  San Francisco
# 314  {'description': 'Honk HQ', 'address1': '625 Se...  San Francisco
# 321  {'description': 'San Francisco HQ', 'address1'...  San Francisco
# 325  {'description': 'Cloudkick', 'address1': '', '...  San Francisco
# 336  {'description': '', 'address1': '363 Clementin...  San Francisco
# 357  {'description': '', 'address1': '550 Montgomer...  San Francisco
# 376  {'description': '', 'address1': '', 'address2'...  San Francisco
# 392  {'description': 'HQ', 'address1': '1355 Market...  San Francisco
# 411  {'description': '', 'address1': 'Pier 38', 'ad...  San Francisco
# 425  {'description': '', 'address1': '', 'address2'...  San Francisco
# 442  {'description': 'Office', 'address1': '', 'add...  San Francisco
# 493  {'description': 'Mashape Lair', 'address1': '4...  San Francisco
# 495  {'description': 'San Franscisco', 'address1': ...  San Francisco
# 514  {'description': '', 'address1': '650 Townsend ...  San Francisco
# 515  {'description': 'Corporate Office', 'address1'...  San Francisco
# 550  {'description': 'SimpleGeo HQ', 'address1': '4...  San Francisco
# 559  {'description': '', 'address1': '', 'address2'...  San Francisco
# 570  {'description': '', 'address1': '901 Mission S...  San Francisco
# 621  {'description': 'Headquarters', 'address1': '5...  San Francisco
# 660  {'description': 'Headquarters', 'address1': '3...  San Francisco
# 665  {'description': 'San Francisco Office', 'addre...  San Francisco
# 682  {'description': 'San Francisco', 'address1': '...  San Francisco
# 700  {'description': '', 'address1': '2 Shaw Alley'...  San Francisco
# 768  {'description': 'TwtBks', 'address1': '442 Sho...  San Francisco
# 790  {'description': 'Headquarters', 'address1': '1...  San Francisco
#
#       latitude   longitude
# 1          NaN         NaN
# 11   37.798853 -122.398599
# 17   37.776659 -122.395875
# 22   37.789349 -122.412893
# 28   37.789629 -122.399878
# 33   37.754332 -122.416804
# 62   37.776399 -122.417716
# 64         NaN         NaN
# 71         NaN         NaN
# 81         NaN         NaN
# 91         NaN         NaN
# 102        NaN         NaN
# 103  39.905226  -86.054702
# 107        NaN         NaN
# 109        NaN         NaN
# 120        NaN         NaN
# 140  37.805324 -122.405276
# 144        NaN         NaN
# 166  37.790554 -122.404149
# 174  37.785271 -122.397582
# 241        NaN         NaN
# 257  37.775196 -122.419204
# 264  37.775196 -122.419204
# 286        NaN         NaN
# 288  37.777995 -122.408914
# 290  37.798318 -122.400003
# 314        NaN         NaN
# 321        NaN         NaN
# 325        NaN         NaN
# 336        NaN         NaN
# 357  37.794482 -122.403074
# 376        NaN         NaN
# 392        NaN         NaN
# 411  37.740594 -122.376471
# 425  37.775196 -122.419204
# 442  37.772323 -122.214897
# 493        NaN         NaN
# 495  37.775300 -122.418600
# 514  37.771018 -122.402598
# 515        NaN         NaN
# 550        NaN         NaN
# 559  37.798318 -122.400003
# 570        NaN         NaN
# 621  37.775206 -122.419209
# 660        NaN         NaN
# 665        NaN         NaN
# 682  37.775196 -122.419204
# 700        NaN         NaN
# 768  37.761102 -122.416001
# 790        NaN         NaN

# %%
df_companies = df_companies.dropna()

# %% [markdown]
# Our final dataframe includes all the cities founded before 2008 in San Francisco with a non-null value for latitude and longitude.

# %%
df_companies
# Out:
#                           name  founded_year  \
# 11                   Widgetbox          2012
# 17                   YouNoodle          2010
# 22                      Ninite          2009
# 28                   Macroaxis          2009
# 33            Supercool School          2009
# 62                     Advisor          2011
# 103                 Formspring          2009
# 140                      Indee          2010
# 166                     Heyzap          2009
# 174                       Meez          2009
# 257            Startup Revival          2009
# 264                     Fliggo          2012
# 288                    MyLikes          2010
# 290  The Vertical Action Group          2009
# 357                 IBWIRE Inc          2009
# 411                    CoTweet          2009
# 425                    Twazzup          2009
# 442                   Shopseen          2013
# 495               LendingKarma          2009
# 514                   Nextstop          2009
# 559                  AppNinjas          2009
# 621                    Fliptop          2010
# 682              Finest Expert          2009
# 768                     TwtBks          2009
#
#                                                offices           city  \
# 11   {'description': None, 'address1': None, 'addre...  San Francisco
# 17   {'description': '', 'address1': '330 Townsend ...  San Francisco
# 22   {'description': '', 'address1': '955 Bush St.'...  San Francisco
# 28   {'description': 'Macroaxis Inc', 'address1': '...  San Francisco
# 33   {'description': None, 'address1': '1176 South ...  San Francisco
# 62   {'description': 'San Francisco HQ', 'address1'...  San Francisco
# 103  {'description': 'Formspring', 'address1': '', ...  San Francisco
# 140  {'description': 'Headquarters', 'address1': '1...  San Francisco
# 166  {'description': 'Head Quaters', 'address1': '3...  San Francisco
# 174  {'description': '', 'address1': '620 Folsom St...  San Francisco
# 257  {'description': 'San Francisco', 'address1': '...  San Francisco
# 264  {'description': '', 'address1': '', 'address2'...  San Francisco
# 288  {'description': '', 'address1': '1000 Brannan ...  San Francisco
# 290  {'description': 'World Headquarters', 'address...  San Francisco
# 357  {'description': '', 'address1': '550 Montgomer...  San Francisco
# 411  {'description': '', 'address1': 'Pier 38', 'ad...  San Francisco
# 425  {'description': '', 'address1': '', 'address2'...  San Francisco
# 442  {'description': 'Office', 'address1': '', 'add...  San Francisco
# 495  {'description': 'San Franscisco', 'address1': ...  San Francisco
# 514  {'description': '', 'address1': '650 Townsend ...  San Francisco
# 559  {'description': '', 'address1': '', 'address2'...  San Francisco
# 621  {'description': 'Headquarters', 'address1': '5...  San Francisco
# 682  {'description': 'San Francisco', 'address1': '...  San Francisco
# 768  {'description': 'TwtBks', 'address1': '442 Sho...  San Francisco
#
#       latitude   longitude
# 11   37.798853 -122.398599
# 17   37.776659 -122.395875
# 22   37.789349 -122.412893
# 28   37.789629 -122.399878
# 33   37.754332 -122.416804
# 62   37.776399 -122.417716
# 103  39.905226  -86.054702
# 140  37.805324 -122.405276
# 166  37.790554 -122.404149
# 174  37.785271 -122.397582
# 257  37.775196 -122.419204
# 264  37.775196 -122.419204
# 288  37.777995 -122.408914
# 290  37.798318 -122.400003
# 357  37.794482 -122.403074
# 411  37.740594 -122.376471
# 425  37.775196 -122.419204
# 442  37.772323 -122.214897
# 495  37.775300 -122.418600
# 514  37.771018 -122.402598
# 559  37.798318 -122.400003
# 621  37.775206 -122.419209
# 682  37.775196 -122.419204
# 768  37.761102 -122.416001
