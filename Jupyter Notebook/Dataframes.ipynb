# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# Once we have called the APIs we will clean and create usefull Dataframes:

# %% [markdown]
# ### Companies Dataframe:

# %%
conn = MongoClient("localhost:27017")
conn.list_database_names()
db = conn.get_database("ironhack")
db.list_collection_names()
# Out:
# ['restaurants', 'books', 'companies', 'countries-small']

# %%
c_companies = db.get_collection("companies")
documents = c_companies.find()

# %%
df_companies = pd.DataFrame(documents)
df_companies.sample(5)
# Out:
#                             _id                  name             permalink  \
# 15216  52cdef7e4bab8bd67529b8fa       Envy Sportswear       envy-sportswear
# 1356   52cdef7c4bab8bd6752982d6              PicScout              picscout
# 13470  52cdef7e4bab8bd67529b228           Pulse Films           pulse-films
# 11992  52cdef7e4bab8bd67529ac62  Unkasoft Advergaming  unkasoft-advergaming
# 15833  52cdef7e4bab8bd67529bb63              SofaWare              sofaware
#
#                                           crunchbase_url  \
# 15216  http://www.crunchbase.com/company/envy-sportswear
# 1356          http://www.crunchbase.com/company/picscout
# 13470      http://www.crunchbase.com/company/pulse-films
# 11992  http://www.crunchbase.com/company/unkasoft-adv...
# 15833         http://www.crunchbase.com/company/sofaware
#
#                     homepage_url                         blog_url  \
# 15216  http://www.angelinasf.com
# ...

# %%
From this df we only need information related to location,

# %% [markdown]
# ### Starbucks Dataframe:
